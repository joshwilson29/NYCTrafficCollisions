# %%
# importing required packages
import pandas as pd
import pandas_profiling
import numpy as np

# %%
# importing the data
accident = pd.read_csv('/Users/sandippalit/Downloads/FARS2017NationalCSV/accident.csv')

# %%
accident.head()
# Out:
#    STATE  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  PERMVIT  \
# 0      1    10001         1         1         0     0           0        1
# 1      1    10002         1         1         0     0           0        1
# 2      1    10003         3         3         0     0           0        3
# 3      1    10004         1         1         0     0           0        1
# 4      1    10005         1         1         0     0           0        2
#
#    PERSONS  COUNTY  ...  NOT_MIN  ARR_HOUR  ARR_MIN  HOSP_HR  HOSP_MN  CF1  \
# 0        1      73  ...       99        99       99       88       88    0
# 1        1      89  ...        0        15        9       88       88    0
# 2        3     101  ...       99        99       99       88       88    0
# 3        1      73  ...       99        16       58       88       88   20
# 4        2      13  ...       17        20       31       21       11    0
#
#    CF2  CF3  FATALS  DRUNK_DR
# 0    0    0       1         0
# ...

# %%
accident.describe()
# Out:
#               STATE        ST_CASE      VE_TOTAL      VE_FORMS      PVH_INVL  \
# count  34247.000000   34247.000000  34247.000000  34247.000000  34247.000000
# mean      27.232079  273067.172599      1.576839      1.537215      0.039624
# std       16.356220  163467.337829      0.833887      0.790691      0.287631
# min        1.000000   10001.000000      1.000000      1.000000      0.000000
# 25%       12.000000  122043.500000      1.000000      1.000000      0.000000
# 50%       26.000000  260857.000000      1.000000      1.000000      0.000000
# 75%       42.000000  420506.500000      2.000000      2.000000      0.000000
# max       56.000000  560105.000000     32.000000     32.000000     11.000000
#
#                PEDS    PERNOTMVIT       PERMVIT       PERSONS        COUNTY  \
# count  34247.000000  34247.000000  34247.000000  34247.000000  34247.000000
# mean       0.217975      0.228283      2.251380      2.261687     91.978567
# ...

# %%
pandas_profiling.ProfileReport(accident)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
FARSprofile = pandas_profiling.ProfileReport(df)
FARSprofile.to_file("/Users/sandippalit/Downloads/FARSprofile.html")

# %%
accident.count()
# Out:
# STATE         34247
# ST_CASE       34247
# VE_TOTAL      34247
# VE_FORMS      34247
# PVH_INVL      34247
# PEDS          34247
# PERNOTMVIT    34247
# PERMVIT       34247
# PERSONS       34247
# COUNTY        34247
# CITY          34247
# DAY           34247
# MONTH         34247
# YEAR          34247
# DAY_WEEK      34247
# HOUR          34247
# MINUTE        34247
# NHS           34247
# RUR_URB       34247
# FUNC_SYS      34247
# RD_OWNER      34247
# ROUTE         34247
# TWAY_ID       34247
# TWAY_ID2       9145
# MILEPT        34247
# LATITUDE      34247
# LONGITUD      34247
# SP_JUR        34247
# HARM_EV       34247
# MAN_COLL      34247
# RELJCT1       34247
# RELJCT2       34247
# TYP_INT       34247
# WRK_ZONE      34247
# REL_ROAD      34247
# LGT_COND      34247
# WEATHER1      34247
# WEATHER2      34247
# WEATHER       34247
# SCH_BUS       34247
# RAIL          34247
# NOT_HOUR      34247
# NOT_MIN       34247
# ARR_HOUR      34247
# ARR_MIN       34247
# ...

# %%
accident.dtypes
# Out:
# STATE           int64
# ST_CASE         int64
# VE_TOTAL        int64
# VE_FORMS        int64
# PVH_INVL        int64
# PEDS            int64
# PERNOTMVIT      int64
# PERMVIT         int64
# PERSONS         int64
# COUNTY          int64
# CITY            int64
# DAY             int64
# MONTH           int64
# YEAR            int64
# DAY_WEEK        int64
# HOUR            int64
# MINUTE          int64
# NHS             int64
# RUR_URB         int64
# FUNC_SYS        int64
# RD_OWNER        int64
# ROUTE           int64
# TWAY_ID        object
# TWAY_ID2       object
# MILEPT          int64
# LATITUDE      float64
# LONGITUD      float64
# SP_JUR          int64
# HARM_EV         int64
# MAN_COLL        int64
# RELJCT1         int64
# RELJCT2         int64
# TYP_INT         int64
# WRK_ZONE        int64
# REL_ROAD        int64
# LGT_COND        int64
# WEATHER1        int64
# WEATHER2        int64
# WEATHER         int64
# SCH_BUS         int64
# RAIL           object
# ...

# %%
accident.isna().sum()
# Out:
# STATE             0
# ST_CASE           0
# VE_TOTAL          0
# VE_FORMS          0
# PVH_INVL          0
# PEDS              0
# PERNOTMVIT        0
# PERMVIT           0
# PERSONS           0
# COUNTY            0
# CITY              0
# DAY               0
# MONTH             0
# YEAR              0
# DAY_WEEK          0
# HOUR              0
# MINUTE            0
# NHS               0
# RUR_URB           0
# FUNC_SYS          0
# RD_OWNER          0
# ROUTE             0
# TWAY_ID           0
# TWAY_ID2      25102
# MILEPT            0
# LATITUDE          0
# LONGITUD          0
# SP_JUR            0
# HARM_EV           0
# MAN_COLL          0
# RELJCT1           0
# RELJCT2           0
# TYP_INT           0
# WRK_ZONE          0
# REL_ROAD          0
# LGT_COND          0
# WEATHER1          0
# WEATHER2          0
# WEATHER           0
# SCH_BUS           0
# RAIL              0
# NOT_HOUR          0
# NOT_MIN           0
# ARR_HOUR          0
# ARR_MIN           0
# ...

# %%
factor = pd.read_csv('/Users/sandippalit/Downloads/FARS2017NationalCSV/factor.csv')

# %%
factor.count()
# Out:
# STATE      52720
# ST_CASE    52720
# VEH_NO     52720
# MFACTOR    52720
# dtype: int64

# %%
factor.isna().sum()
# Out:
# STATE      0
# ST_CASE    0
# VEH_NO     0
# MFACTOR    0
# dtype: int64

# %%
Maneuver = pd.read_csv('/Users/sandippalit/Downloads/FARS2017NationalCSV/Maneuver.csv')

# %%
Maneuver.isna().sum()
# Out:
# STATE       0
# ST_CASE     0
# VEH_NO      0
# MDRMANAV    0
# dtype: int64

# %%
Distract = pd.read_csv('/Users/sandippalit/Downloads/FARS2017NationalCSV/Distract.csv')

# %%
Distract.isna().sum()
# Out:
# STATE       0
# ST_CASE     0
# VEH_NO      0
# MDRDSTRD    0
# dtype: int64

# %%
Vision = pd.read_csv('/Users/sandippalit/Downloads/FARS2017NationalCSV/Vision.csv')

# %%
Vision.isna().sum()
# Out:
# STATE       0
# ST_CASE     0
# VEH_NO      0
# MVISOBSC    0
# dtype: int64

# %%
Violation = pd.read_csv('/Users/sandippalit/Downloads/FARS2017NationalCSV/Violatn.csv')

# %%
Violation.head()
# Out:
#    STATE  ST_CASE  VEH_NO  MVIOLATN
# 0      1    10001       1         0
# 1      1    10002       1         0
# 2      1    10003       1         0
# 3      1    10003       2         0
# 4      1    10003       3         0

# %%
Violation.isna().sum()
# Out:
# STATE       0
# ST_CASE     0
# VEH_NO      0
# MVIOLATN    0
# dtype: int64

# %%
person = pd.read_csv('/Users/sandippalit/Downloads/FARS2017NationalCSV/person.csv')

# %%
person.isna().sum()
# Out:
# STATE            0
# ST_CASE          0
# VE_FORMS         0
# VEH_NO           0
# PER_NO           0
# STR_VEH          0
# COUNTY           0
# DAY              0
# MONTH            0
# HOUR             0
# MINUTE           0
# RUR_URB          0
# FUNC_SYS         0
# HARM_EV          0
# MAN_COLL         0
# SCH_BUS          0
# MAKE          7465
# MAK_MOD       7465
# BODY_TYP      7465
# MOD_YEAR      7465
# TOW_VEH       7465
# SPEC_USE      7465
# EMER_USE      7465
# ROLLOVER      7465
# IMPACT1       7465
# FIRE_EXP      7465
# AGE              0
# SEX              0
# PER_TYP          0
# INJ_SEV          0
#               ...
# ALC_DET          0
# ALC_STATUS       0
# ATST_TYP         0
# ALC_RES          0
# DRUGS            0
# DRUG_DET         0
# DSTATUS          0
# DRUGTST1         0
# DRUGTST2         0
# DRUGTST3         0
# DRUGRES1         0
# DRUGRES2         0
# DRUGRES3         0
# HOSPITAL         0
# DOA              0
# DEATH_DA         0
# ...

# %%
person.count()
# Out:
# STATE         84921
# ST_CASE       84921
# VE_FORMS      84921
# VEH_NO        84921
# PER_NO        84921
# STR_VEH       84921
# COUNTY        84921
# DAY           84921
# MONTH         84921
# HOUR          84921
# MINUTE        84921
# RUR_URB       84921
# FUNC_SYS      84921
# HARM_EV       84921
# MAN_COLL      84921
# SCH_BUS       84921
# MAKE          77456
# MAK_MOD       77456
# BODY_TYP      77456
# MOD_YEAR      77456
# TOW_VEH       77456
# SPEC_USE      77456
# EMER_USE      77456
# ROLLOVER      77456
# IMPACT1       77456
# FIRE_EXP      77456
# AGE           84921
# SEX           84921
# PER_TYP       84921
# INJ_SEV       84921
#               ...
# ALC_DET       84921
# ALC_STATUS    84921
# ATST_TYP      84921
# ALC_RES       84921
# DRUGS         84921
# DRUG_DET      84921
# DSTATUS       84921
# DRUGTST1      84921
# DRUGTST2      84921
# DRUGTST3      84921
# DRUGRES1      84921
# DRUGRES2      84921
# DRUGRES3      84921
# HOSPITAL      84921
# ...

# %%
accident_factor_2017 = pd.merge(accident,factor, on ='ST_CASE',how ='left')

# %%
accident_factor_2017.head()
# Out:
#    STATE_x  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  PERMVIT  \
# 0        1    10001         1         1         0     0           0        1
# 1        1    10002         1         1         0     0           0        1
# 2        1    10003         3         3         0     0           0        3
# 3        1    10003         3         3         0     0           0        3
# 4        1    10003         3         3         0     0           0        3
#
#    PERSONS  COUNTY  ...  HOSP_HR  HOSP_MN  CF1  CF2  CF3  FATALS  DRUNK_DR  \
# 0        1      73  ...       88       88    0    0    0       1         0
# 1        1      89  ...       88       88    0    0    0       1         0
# 2        3     101  ...       88       88    0    0    0       1         0
# 3        3     101  ...       88       88    0    0    0       1         0
# 4        3     101  ...       88       88    0    0    0       1         0
#
#    STATE_y  VEH_NO  MFACTOR
# ...

# %%
accident_factor_distract_2017 = pd.merge(accident_factor_2017,Distract, on ='ST_CASE',how ='left')

# %%
accident_factor_distract_2017.head()
# Out:
#    STATE_x  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  PERMVIT  \
# 0        1    10001         1         1         0     0           0        1
# 1        1    10002         1         1         0     0           0        1
# 2        1    10003         3         3         0     0           0        3
# 3        1    10003         3         3         0     0           0        3
# 4        1    10003         3         3         0     0           0        3
#
#    PERSONS  COUNTY  ...  CF2  CF3  FATALS  DRUNK_DR  STATE_y  VEH_NO_x  \
# 0        1      73  ...    0    0       1         0        1         1
# 1        1      89  ...    0    0       1         0        1         1
# 2        3     101  ...    0    0       1         0        1         1
# 3        3     101  ...    0    0       1         0        1         1
# 4        3     101  ...    0    0       1         0        1         1
#
#    MFACTOR  STATE  VEH_NO_y  MDRDSTRD
# ...

# %%
accident_factor_distract_Maneuver_2017 = pd.merge(accident_factor_distract_2017,Maneuver, on ='ST_CASE',how ='left')

# %%
accident_factor_distract_Maneuver_2017.head()
# Out:
#    STATE_x  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  PERMVIT  \
# 0        1    10001         1         1         0     0           0        1
# 1        1    10002         1         1         0     0           0        1
# 2        1    10003         3         3         0     0           0        3
# 3        1    10003         3         3         0     0           0        3
# 4        1    10003         3         3         0     0           0        3
#
#    PERSONS  COUNTY  ...  DRUNK_DR  STATE_y  VEH_NO_x  MFACTOR  STATE_x  \
# 0        1      73  ...         0        1         1        0        1
# 1        1      89  ...         0        1         1        0        1
# 2        3     101  ...         0        1         1        0        1
# 3        3     101  ...         0        1         1        0        1
# 4        3     101  ...         0        1         1        0        1
#
#    VEH_NO_y  MDRDSTRD  STATE_y  VEH_NO  MDRMANAV
# ...

# %%
accident_factor_distract_Maneuver_Vision_2017 = pd.merge(accident_factor_distract_Maneuver_2017,Vision, on ='ST_CASE',how ='left')

# %%
accident_factor_distract_Maneuver_Vision_2017.head()
# Out:
#    STATE_x  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  PERMVIT  \
# 0        1    10001         1         1         0     0           0        1
# 1        1    10002         1         1         0     0           0        1
# 2        1    10003         3         3         0     0           0        3
# 3        1    10003         3         3         0     0           0        3
# 4        1    10003         3         3         0     0           0        3
#
#    PERSONS  COUNTY  ...  MFACTOR  STATE_x  VEH_NO_y  MDRDSTRD  STATE_y  \
# 0        1      73  ...        0        1         1         0        1
# 1        1      89  ...        0        1         1         0        1
# 2        3     101  ...        0        1         1        99        1
# 3        3     101  ...        0        1         1        99        1
# 4        3     101  ...        0        1         1        99        1
#
#    VEH_NO_x  MDRMANAV  STATE  VEH_NO_y  MVISOBSC
# ...

# %%
acc_fc_dis_mn_vi_vl_2017= pd.merge(accident_factor_distract_Maneuver_Vision_2017,Violation, on ='ST_CASE',how ='left')

# %%
acc_fc_dis_mn_vi_vl_2017.head()
# Out:
#    STATE_x  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  PERMVIT  \
# 0        1    10001         1         1         0     0           0        1
# 1        1    10002         1         1         0     0           0        1
# 2        1    10003         3         3         0     0           0        3
# 3        1    10003         3         3         0     0           0        3
# 4        1    10003         3         3         0     0           0        3
#
#    PERSONS  COUNTY  ...  MDRDSTRD  STATE_y  VEH_NO_x  MDRMANAV  STATE_x  \
# 0        1      73  ...         0        1         1        98        1
# 1        1      89  ...         0        1         1        98        1
# 2        3     101  ...        99        1         1        98        1
# 3        3     101  ...        99        1         1        98        1
# 4        3     101  ...        99        1         1        98        1
#
#    VEH_NO_y  MVISOBSC  STATE_y  VEH_NO  MVIOLATN
# ...

# %%
acc_fc_dis_mn_vi_vl_2017.columns
# Out:
# Index(['STATE_x', 'ST_CASE', 'VE_TOTAL', 'VE_FORMS', 'PVH_INVL', 'PEDS',
#        'PERNOTMVIT', 'PERMVIT', 'PERSONS', 'COUNTY', 'CITY', 'DAY', 'MONTH',
#        'YEAR', 'DAY_WEEK', 'HOUR', 'MINUTE', 'NHS', 'RUR_URB', 'FUNC_SYS',
#        'RD_OWNER', 'ROUTE', 'TWAY_ID', 'TWAY_ID2', 'MILEPT', 'LATITUDE',
#        'LONGITUD', 'SP_JUR', 'HARM_EV', 'MAN_COLL', 'RELJCT1', 'RELJCT2',
#        'TYP_INT', 'WRK_ZONE', 'REL_ROAD', 'LGT_COND', 'WEATHER1', 'WEATHER2',
#        'WEATHER', 'SCH_BUS', 'RAIL', 'NOT_HOUR', 'NOT_MIN', 'ARR_HOUR',
#        'ARR_MIN', 'HOSP_HR', 'HOSP_MN', 'CF1', 'CF2', 'CF3', 'FATALS',
#        'DRUNK_DR', 'STATE_y', 'VEH_NO_x', 'MFACTOR', 'STATE_x', 'VEH_NO_y',
#        'MDRDSTRD', 'STATE_y', 'VEH_NO_x', 'MDRMANAV', 'STATE_x', 'VEH_NO_y',
#        'MVISOBSC', 'STATE_y', 'VEH_NO', 'MVIOLATN'],
#       dtype='object')

# %%
FARS_2017_combined= acc_fc_dis_mn_vi_vl_2017[['STATE_x', 'ST_CASE', 'PERSONS','CITY','DAY','MONTH','YEAR','DAY_WEEK',
'HOUR','NHS','RUR_URB','FUNC_SYS','ROUTE','LATITUDE','LONGITUD','HARM_EV','MAN_COLL','RELJCT1','RELJCT2','TYP_INT',
'WRK_ZONE','REL_ROAD','LGT_COND','WEATHER1','WEATHER2','WEATHER',
'SCH_BUS','RAIL','CF1','CF2','CF3','MFACTOR','MDRMANAV','MDRDSTRD',
'MVISOBSC','MVIOLATN']]

# %%
FARS_2017_combined.head()
# Out:
#    STATE_x  STATE_x  STATE_x  ST_CASE  PERSONS  CITY  DAY  MONTH  YEAR  \
# 0        1        1        1    10001        1   330   19      2  2017
# 1        1        1        1    10002        1  1730   14      2  2017
# 2        1        1        1    10003        3  2130   31      1  2017
# 3        1        1        1    10003        3  2130   31      1  2017
# 4        1        1        1    10003        3  2130   31      1  2017
#
#    DAY_WEEK  ...  SCH_BUS     RAIL  CF1  CF2  CF3  MFACTOR  MDRMANAV  \
# 0         1  ...        0  725409J    0    0    0        0        98
# 1         3  ...        0  0000000    0    0    0        0        98
# 2         3  ...        0  0000000    0    0    0        0        98
# 3         3  ...        0  0000000    0    0    0        0        98
# 4         3  ...        0  0000000    0    0    0        0        98
#
#    MDRDSTRD  MVISOBSC  MVIOLATN
# 0         0         0         0
# 1         0         0         0
# ...

# %%
FARS_2017_combined_2= pd.merge(FARS_2017_combined,person, on ='ST_CASE',how ='left')

# %%
pd.DataFrame.to_csv(FARS_2017_combined, 'FARS_merged.csv', sep=',', na_rep='.', index=False)
